# %%
#################### PAQUETES #######################################


import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
#################### CONDICIONES INICIALES ######################

n=100000
inicio=0
fin=100
X=np.zeros(n)
V=np.zeros(n)
T=np.zeros(n)
dt=(fin-inicio)/n
X[0]=1
V[0]=0
T[0]=0


#################### FUNCION #######################################
def funcion (x,A):
    return -A*X[i]

#################### ITERACION #######################################

#Se usa el método numérico de euler para resolver la ecuación
for i in range(1,n):
    T[i] = T[i-1] + dt
    X[i] = X[i-1] + dt * V[i-1]
    V[i] = V[i-1] + dt * funcion(X[i-1],0.5)

    

    
X2=np.zeros(n)
V2=np.zeros(n)
T2=np.zeros(n)
X2[0]=1
V2[0]=0
T2[0]=0

#################### ITERACION #######################################


for i in range(1,n):
    T2[i] = T2[i-1] + dt
    X2[i] = X2[i-1] + dt * V2[i-1]
    V2[i] = V2[i-1] + dt * funcion(X2[i-1],0.7)

    

X3=np.zeros(n)
V3=np.zeros(n)
T3=np.zeros(n)
X3[0]=1
V3[0]=0
T3[0]=0

#################### ITERACION #######################################


for i in range(1,n):
    T3[i] = T3[i-1] + dt
    X3[i] = X3[i-1] + dt * V3[i-1]
    V3[i] = V3[i-1] + dt * funcion(X3[i-1],1)

# %%
plt.plot(T,X,color="c",label="A=0.5")
plt.plot(T2,X2,color="b",label="A=0.7")
plt.plot(T3,X3,color="black",label="A=1")
plt.legend()
# Out:
# C:\Users\david\Anaconda3\lib\site-packages\IPython\core\events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\david\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
